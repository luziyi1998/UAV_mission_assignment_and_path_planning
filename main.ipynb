# %%
import imp
imp.reload(main)
from main import *

# %%
# paramete
N_depots = 4
N_drones = 20
N_packages = 60
N_transit_edges = 20
Max_flight = 500

# %%
drone_one_dilivery_route, drone_one_delivery_time_stamp, drone_one_dilivery_time, fail_packages = UAV_task_allocation_path_planning(N_depots, N_transit_edges, N_packages, N_drones, Max_flight)
# Out:
# do task allocation
# task allocation done
# /Users/luzy6/PycharmProjects/UAV_mission_assignment_and_path_planning/task_allocation_layer/task_allocation.py:133: OptimizeWarning: Sparse constraint matrix detected; setting 'sparse':True.
#   res = linprog(c=cost_vector, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq,
# /Users/luzy6/miniforge3/envs/UAV/lib/python3.9/site-packages/scipy/optimize/_linprog_util.py:843: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning, stacklevel=1)
# /Users/luzy6/PycharmProjects/UAV_mission_assignment_and_path_planning/MAPF/single_drone_FP.py:264: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   res = linprog(c=time_cost_vector, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq,
# 76.0 to 13.0 True
# 76.0  to 13.0 route_plan_distance_cost 240.35110574454683
# route: [76.0, 69.0, 58.0, 13.0]
# use time 34.44149088491889
#
# 76.0 to 42.0 True
# 76.0  to 42.0 route_plan_distance_cost 133.30044618854797
# route: [76.0, 42.0]
# use time 6.665022309427398
#
# 76.0 to 61.0 True
# 76.0  to 61.0 route_plan_distance_cost 103.87452321513088
# route: [76.0, 61.0]
# use time 5.193726160756544
#
# 76.0 to 66.0 True
# 76.0  to 66.0 route_plan_distance_cost 116.7216297773179
# route: [76.0, 66.0]
# use time 5.836081488865895
#
# 76.0 to 73.0 True
# 76.0  to 73.0 route_plan_distance_cost 95.92169469312407
# route: [76.0, 73.0]
# use time 4.796084734656203
#
# 76.0 to 98.0 True
# 76.0  to 98.0 route_plan_distance_cost 109.97218484289499
# route: [76.0, 98.0]
# use time 5.49860924214475
#
# 76.0 to 183.0 True
# 76.0  to 183.0 route_plan_distance_cost 115.48255684846048
# route: [76.0, 183.0]
# use time 5.774127842423024
# /Users/luzy6/PycharmProjects/UAV_mission_assignment_and_path_planning/MAPF/single_drone_FP.py:264: OptimizeWarning: Solving system with option 'cholesky':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'cholesky' to False.
#   res = linprog(c=time_cost_vector, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq,
# /Users/luzy6/PycharmProjects/UAV_mission_assignment_and_path_planning/MAPF/single_drone_FP.py:264: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
#   res = linprog(c=time_cost_vector, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq,
# /Users/luzy6/miniforge3/envs/UAV/lib/python3.9/site-packages/scipy/optimize/_linprog_ip.py:117: LinAlgWarning: Ill-conditioned matrix (rcond=5.38217e-27): result may not be accurate.
#   return sp.linalg.solve(M, r, sym_pos=sym_pos)
# 132.0 to 5.0 True
# 132.0  to 5.0 route_plan_distance_cost 220.42622368791396
# route: [132.0, 5.0]
# use time 11.021311184395698
#
# 132.0 to 8.0 False
#
# 132.0 to 9.0 False
#
# 132.0 to 10.0 False
#
# 132.0 to 45.0 False
#
# 132.0 to 131.0 True
# 132.0  to 131.0 route_plan_distance_cost 49.63204702349125
# route: [132.0, 131.0]
# use time 2.481602351174563
#
# 132.0 to 190.0 True
# 132.0  to 190.0 route_plan_distance_cost 192.62789018968894
# route: [132.0, 125.0, 110.0, 190.0]
# use time 19.54200438085998
#
# 132.0 to 208.0 True
# 132.0  to 208.0 route_plan_distance_cost 272.3659883784699
# route: [132.0, 125.0, 110.0, 208.0]
# use time 23.528909290299033
#
# 136.0 to 137.0 True
# 136.0  to 137.0 route_plan_distance_cost 10.681263222873877
# route: [136.0, 137.0]
# use time 0.5340631611436939

# %%
for (route, time_stamp, time) in zip(drone_one_dilivery_route, drone_one_delivery_time_stamp, drone_one_dilivery_time):
    print("route:", route)
    print("time_stamp", time_stamp)
    print("time", time)
print("fail deliveries", fail_packages)
# Out:
# route: [76.0, 69.0, 58.0, 13.0]
# time_stamp [0.0, 8.098404811002535, 30.52234040869408, 34.44149088491889]
# time 34.44149088491889
# route: [76.0, 42.0]
# time_stamp [0.0, 6.665022309427398]
# time 6.665022309427398
# route: [76.0, 61.0]
# time_stamp [0.0, 5.193726160756544]
# time 5.193726160756544
# route: [76.0, 66.0]
# time_stamp [0.0, 5.836081488865895]
# time 5.836081488865895
# route: [76.0, 73.0]
# time_stamp [0.0, 4.796084734656203]
# time 4.796084734656203
# route: [76.0, 98.0]
# time_stamp [0.0, 5.49860924214475]
# time 5.49860924214475
# route: [76.0, 183.0]
# time_stamp [0.0, 5.774127842423024]
# time 5.774127842423024
# route: [132.0, 5.0]
# time_stamp [0.0, 11.021311184395698]
# time 11.021311184395698
# route: []
# time_stamp [0]
# time -1
# route: []
# time_stamp [0]
# time -1
# route: []
# time_stamp [0]
# time -1
# route: []
# time_stamp [0]
# time -1
# route: [132.0, 131.0]
# time_stamp [0.0, 2.481602351174563]
# time 2.481602351174563
# route: [132.0, 125.0, 110.0, 190.0]
# time_stamp [0.0, 0.32494388315541683, 10.235553754530951, 19.54200438085998]
# time 19.54200438085998
# route: [132.0, 125.0, 110.0, 208.0]
# time_stamp [0.0, 0.32494388315541683, 10.235553754530951, 23.528909290299033]
# time 23.528909290299033
# route: [136.0, 137.0]
# time_stamp [0.0, 0.5340631611436939]
# time 0.5340631611436939
# fail deliveries [8.0, 9.0, 10.0, 45.0]

# %%
a = [1,2,3,4,5]

# %%
a[0:5]
# Out:
# [1, 2, 3, 4, 5]
